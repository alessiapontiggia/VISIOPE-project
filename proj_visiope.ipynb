# %% [markdown]
# <a href="https://colab.research.google.com/github/alessiapontiggia/VISIOPE-project/blob/main/proj_visiope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This paper shows the task I want to deal with: the goal line technology.
# Its aim is about deciding if a goal is valid or not (i.e. checking if the ball has entirly passed the goal line).
# To do this, there will be shown two techniques:
#
# *   Detections of the ball and the line to determine if that ball has passed that line.
# *  Learning with a CNN if a goal is valid or not from a dataset of images.

# %% [markdown]
# Utils 1: libreries and functions
# Below, you can see the libreries I import and the functions I use to develop the project. At each section, they are described in details.

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import matplotlib.patheffects as path_effects
import random

# %%
def read_image(img_path):
  img = cv.imread(img_path)
  return img

# %%
def convert_bgr_to_rgb(img_bgr):
  img_rgb = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)
  return img_rgb

# %%
def show_image(img, title):
  plt.axis('off')
  plt.imshow(img)
  plt.title(title)
  return

# %%
def building_image():
  # random image dimensions
  y = random.randint(200, 300)
  x = random.randint(300, 400)
  img_shape = (y, x, 3)
  
  # random background color in the shape of a green pitch
  green = random.randint(150,255)
  red = random.randint(1,30)
  blue = random.randint(1,30)
  background_color = (red,green,blue)
  background = np.full(img_shape, background_color, dtype=np.uint8)
  
  # white line in a vertical plane (0) or horizontal plane (1) at random position
  choice = random.randint(0,1)
  match choice:
    case 0:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      x_line = random.randint(x_mean-100, x_mean+100)
      y_start = -1500
      y_end = 1500
      pt1 = (x_line, y_start)
      pt2 = (x_line, y_end)
      cv.line(background, pt1, pt2, line_color, 20)
    case 1:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      y_line = random.randint(y_mean-50, y_mean+50)
      x_start = -1500
      x_end = 1500
      pt1 = (x_start, y_line)
      pt2 = (x_end, y_line)
      cv.line(background, pt1, pt2, line_color, 20)
      

  # circle (ball) in a random position
  x_c = random.randint(x_mean-50, x_mean+50)
  y_c = random.randint(y_mean-50, y_mean+50)
  center_ball = (x_c, y_c)
  radius = random.randint(20, 30)
  ball_color = (200,200,200)
  cv.circle(background, center_ball, radius, ball_color, cv.FILLED)
  
  return background

# %%
def generate_dataset(data_path):
  n_img = int(input("Insert the number if images you want to generate for the dataset: "))
  for i in range(0, n_img):
    path = data_path+"/img_"+str(i)+".png"
    img = building_image()
    cv.imwrite(path, img)
  print("Dataset generated. You can find the images in your Drive under ", data_path)
  return n_img

# %%
def ball_detection(original_img, edges_img):
  circles = cv.HoughCircles(edges_img, cv.HOUGH_GRADIENT, 1, 20, param1 = 100,
               param2 = 20, minRadius = 0, maxRadius = 0)
  detected = original_img.copy()
  points = {}
  points["x"] = []
  points["y"] = []
  if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
      cv.circle(detected, (x, y), r, (255, 0, 0), 2)
      points["x"].append(x+r)
      points["x"].append(x-r)
      points["y"].append(y+r)
      points["y"].append(y-r)
    return points, detected
  else:
    print('No ball detected.\n')
    return

# %%
def extrema_line(img, extrema, h_or_v):
  shape = img.shape
  result = img.copy()
  ball_lines = []
  if extrema is not None:
    for key in extrema:
      match h_or_v:
        case 1:
          if key=="x":
            for value in extrema[key]:
              start = (value, -1500)
              end = (value, 1500)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
        case 0:
          if key=="y":
            for value in extrema[key]:
              start = (-1500, value)
              end = (1500, value)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
  else:
    print("No line projections of the ball because no ball was found.\n")
  return ball_lines, result

# %%
def line_detection(img):
  
  result = img.copy()
  gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
  canny = cv.Canny(gray, 100, 200)
  lines = cv.HoughLines(canny, 1, np.pi/180,  150, None, 0, 0)
  
  goal_lines = []
  if lines is not None:
    for i in range(0, len(lines)):
      rho = lines[i][0][0]
      theta = lines[i][0][1]
      a = np.cos(theta)
      b = np.sin(theta)
      x0 = a * rho
      y0 = b * rho
      pt1 = (int(x0 + 1500*(-b)), int(y0 + 1500*(a)))
      pt2 = (int(x0 - 1500*(-b)), int(y0 - 1500*(a)))
      cv.line(result, pt1, pt2, (0,0,255), 3, cv.LINE_AA)
      goal_lines.append(pt1)
      goal_lines.append(pt2)
    return goal_lines, result
  else:
    print("No Line Detected.\n")
    return [], result

# %%
def from_tuples_to_coordinates(tuples, val):
  result = []
  if tuples is not None and len(tuples)>0:
    for t in tuples:
      match val:
        case "x":
          result.append(t[0])
        case "y":
          result.append(t[1])
  return result

# %%
def horizontal_vertical_line(goal_lines, img):
  
  dim_x = img.shape[1]
  dim_y = img.shape[0]

  x = from_tuples_to_coordinates(goal_lines, val="x")
  y = from_tuples_to_coordinates(goal_lines, val="y")

  if len(x) > 0:
    max_x = max(x)
    if max_x > dim_x:
      return 0          # horizontal line
  
  if len(y) > 0:
    max_y = max(y)
    if max_y > dim_y:
      return 1          # vertical line
  
  return "No line was found"

# %%
def var_check(img, ball_lines, goal_lines):

  if len(ball_lines)==0:
    print("No ball was found\n")
    return
  if len(goal_lines)==0:
    print("No line was found\n")
    return 

  h_v = horizontal_vertical_line(goal_lines, img)
  match h_v: 
    case 0:
      ball_y_coordinates = from_tuples_to_coordinates(ball_lines, val="y")
      line_y_coordinates = from_tuples_to_coordinates(goal_lines, val="y")
      max_y_ball = max(ball_y_coordinates)
      min_y_ball = min(ball_y_coordinates)
      max_y_line = max(line_y_coordinates)
      min_y_line = min(line_y_coordinates)
      if min_y_ball > max_y_line or max_y_ball < min_y_line:
        return 1
      else:
        return 0 
    case 1:
      ball_x_coordinates = from_tuples_to_coordinates(ball_lines, val="x")
      line_x_coordinates = from_tuples_to_coordinates(goal_lines, val="x")
      max_x_ball = max(ball_x_coordinates)
      min_x_ball = min(ball_x_coordinates)
      max_x_line = max(line_x_coordinates)
      min_x_line = min(line_x_coordinates)
      if min_x_ball > max_x_line or max_x_ball < min_x_line:
        return 1
      else:
        return 0

# %%
def test(n, src_path, dst_path):
  for i in range(0,n):
    img_path = src_path+'/img_'+str(i)+".png"
    img = convert_bgr_to_rgb(read_image(img_path))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    edges = cv.Canny(gray,100,200)
    points, img_ball_detected = ball_detection(img, edges)
    goal_lines, img_line_detection = line_detection(img)
    h_or_v = horizontal_vertical_line(goal_lines, img)
    ball_lines, img_ball_lines = extrema_line(img, points, h_or_v)
    g = var_check(img, ball_lines, goal_lines)
    if g == 0:
      print("The image: "+str(img_path)+" has a NO GOAL")
      img_no_goal_path = dst_path+'/No_Goal/img_'+str(i)+".png"
      cv.imwrite(img_no_goal_path,img)
    elif g == 1:
      print("The image: "+str(img_path)+" has a GOAL")
      img_goal_path = dst_path+'/Goal/img_'+str(i)+".png"
      cv.imwrite(img_goal_path, img)
    else:
      print("The image: "+str(img_path)+" occured an error\n")
  return

# %% [markdown]
# # Building Dataset

# %% [markdown]
# To have a more various and a deeper set of images, unavailable online, I provide it by myself.
#
# The function **generate_dataset** calls n times the **building_image** function, where n is an input value and represents the size of the dataset (i.e. the number of images).
#
# The images generated are stored in /content/drive/MyDrive/VISIOPE/dataset path.
# These frames are made of 3 main parts:
#
#
# 1.   A green background: the pitch
# 2.   A filled circle: the ball
# 3.   A vertical or horizontal white line: the goal line
#
# Positions, dimensions and colors of these components are picked randomically.

# %%
training_path = training_path = "/content/drive/MyDrive/VISIOPE/dataset"
n_img = generate_dataset(training_path)
# Out:
# Insert the number if images you want to generate for the dataset: 2000
# Dataset generated. You can find the images in your Drive under  /content/drive/MyDrive/VISIOPE/dataset

# %% [markdown]
# # Computer Vision - oriented solution

# %% [markdown]
# # Image Processing
#
# First thing to do is reading the input image. So we use the **read_image** and the **convert_bgr_to_rgb** functions to read and convert the image in the color space we want (RGB).
#
# Then we apply the Canny Edge Detector on the gray scale image, it will be used to have a clearer representation of the shapes.
#
# The input image, the gray scale image, and the Canny Edge image application are then shown with **show_image** function.
#
# Below an example:

# %%
random_img_index = random.randint(0, 2000)
img_path = '/content/drive/MyDrive/VISIOPE/dataset/img_'+str(random_img_index)+".png"
img = convert_bgr_to_rgb(read_image(img_path))
show_image(img, title="input image")
img_shape = img.shape
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,100,200)

# %%
fig, axs = plt.subplots(1, 3)
plt.figure(figsize=(3,5))
axs[0].imshow(img)
axs[0].set_title('Input Image')
axs[1].imshow(gray)
axs[1].set_title('Gray Scale Image')
axs[2].imshow(edges)
axs[2].set_title('Edge Detector Applied')
# Out:
# Text(0.5, 1.0, 'Edge Detector Applied')

# %% [markdown]
# # Detection of the ball
#
# Since the ball has a circular shape, it's used the openCV **Hough Circles** algorithm to detect the ball in the **ball_detection** function.
# The function I implemented returns as first parameter a dictionary where the keys are coordinates (x and y), and the values are the 4 points (2 for the key "x" and the other 2 for the key "y") at the highest distance (radius) from the center of the circle. The second parameter returned by the ball detection function is a copy of the input image with the circle (ball) underlined.

# %%
points, img_ball_detected = ball_detection(img, edges)
show_image(img_ball_detected, title="Ball detection")

# %% [markdown]
# # Goal line Detection
#
# To detect the goal line it's used the openCV algorithm **HoughLines** in the **line_detection** function.
#
# The goal line is made up of two lines (boundaries).
#
# So this function returns a list of the points through which the lines pass.

# %%
goal_lines, img_line_detection = line_detection(img)
show_image(img_line_detection, title="Line Detection")

# %% [markdown]
# # Goal Or No Goal?
#
# To understand if a goal is valid or not, I first check if:
# - the goal line is vertical
# - the goal line is horizontal

# %% [markdown]
# To understand if the goal line lies on a vertical or on a horizontal axis, I use the **horizontal_vertical_line** function that controls the value of the points through which the lines pass.
#
# This function returns 0 if the line is horizontal or 1 if the line is vertical.

# %%
h_or_v = horizontal_vertical_line(goal_lines, img)

# %% [markdown]
# Once I checked this, I focus on the vertical or horizontal line projections of the ball according to the vertical or horizontal axis of the goal line.

# %%
ball_lines, img_ball_lines = extrema_line(img, points, h_or_v)
show_image(img_ball_lines, title="Projection lines of the ball")

# %% [markdown]
# Now, to see if the ball has entirly passed the goal line, I describe below the mechanism I used in the **goal_no_goal** function.
#
# *In the vertical case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the x axis)
#
# *In the horizontal case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball line coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the y axis)

# %%
val = var_check(img, ball_lines, goal_lines)
if val == 1:
  print("GOAL")
elif val == 0:
  print("NO GOAL")
else:
  print("Something went wrong...")
# Out:
# GOAL

# %% [markdown]
# # Results
#
# Now we want to see the results on the entire dataset of the first method described above. This is done by the function **test**.

# %%
test(n_img, src_path = "/content/drive/MyDrive/VISIOPE/dataset", dst_path = "/content/drive/MyDrive/VISIOPE/training")
# Out:
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_0.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_3.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_5.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_6.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_7.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_8.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_9.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_10.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_11.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_12.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_13.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_14.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_15.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_16.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_17.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_18.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_19.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_20.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_21.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_22.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_23.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_24.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_25.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_26.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_27.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_28.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_29.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_30.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_31.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_32.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_33.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_34.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_35.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_36.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_37.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_38.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_39.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_40.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_41.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_42.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_43.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_44.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_45.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_46.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_47.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_48.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_49.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_50.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_51.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_52.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_53.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_54.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_55.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_56.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_57.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_58.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_59.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_60.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_61.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_62.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_63.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_64.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_65.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_66.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_67.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_68.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_69.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_70.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_71.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_72.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_73.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_74.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_75.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_76.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_77.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_78.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_79.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_80.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_81.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_82.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_83.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_84.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_85.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_86.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_87.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_88.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_89.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_90.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_91.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_92.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_93.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_94.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_95.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_96.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_97.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_98.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_99.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_100.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_101.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_102.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_103.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_104.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_105.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_106.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_107.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_108.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_109.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_110.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_111.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_112.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_113.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_114.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_115.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_116.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_117.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_118.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_119.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_120.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_121.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_122.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_123.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_124.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_125.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_126.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_127.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_128.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_129.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_130.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_131.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_132.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_133.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_134.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_135.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_136.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_137.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_138.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_139.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_140.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_141.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_142.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_143.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_144.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_145.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_146.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_147.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_148.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_149.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_150.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_151.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_152.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_153.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_154.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_155.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_156.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_157.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_158.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_159.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_160.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_161.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_162.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_163.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_164.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_165.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_166.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_167.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_168.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_169.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_170.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_171.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_172.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_173.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_174.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_175.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_176.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_177.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_178.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_179.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_180.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_181.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_182.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_183.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_184.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_185.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_186.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_187.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_188.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_189.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_190.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_191.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_192.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_193.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_194.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_195.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_196.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_197.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_198.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_199.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_200.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_201.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_202.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_203.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_204.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_205.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_206.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_207.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_208.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_209.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_210.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_211.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_212.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_213.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_214.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_215.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_216.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_217.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_218.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_219.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_220.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_221.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_222.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_223.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_224.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_225.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_226.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_227.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_228.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_229.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_230.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_231.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_232.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_233.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_234.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_235.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_236.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_237.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_238.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_239.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_240.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_241.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_242.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_243.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_244.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_245.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_246.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_247.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_248.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_249.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_250.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_251.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_252.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_253.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_254.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_255.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_256.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_257.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_258.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_259.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_260.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_261.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_262.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_263.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_264.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_265.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_266.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_267.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_268.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_269.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_270.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_271.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_272.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_273.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_274.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_275.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_276.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_277.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_278.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_279.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_280.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_281.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_282.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_283.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_284.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_285.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_286.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_287.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_288.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_289.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_290.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_291.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_292.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_293.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_294.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_295.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_296.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_297.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_298.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_299.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_300.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_301.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_302.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_303.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_304.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_305.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_306.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_307.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_308.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_309.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_310.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_311.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_312.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_313.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_314.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_315.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_316.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_317.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_318.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_319.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_320.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_321.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_322.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_323.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_324.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_325.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_326.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_327.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_328.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_329.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_330.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_331.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_332.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_333.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_334.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_335.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_336.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_337.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_338.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_339.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_340.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_341.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_342.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_343.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_344.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_345.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_346.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_347.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_348.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_349.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_350.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_351.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_352.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_353.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_354.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_355.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_356.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_357.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_358.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_359.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_360.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_361.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_362.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_363.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_364.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_365.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_366.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_367.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_368.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_369.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_370.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_371.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_372.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_373.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_374.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_375.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_376.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_377.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_378.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_379.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_380.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_381.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_382.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_383.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_384.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_385.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_386.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_387.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_388.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_389.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_390.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_391.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_392.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_393.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_394.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_395.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_396.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_397.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_398.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_399.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_400.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_401.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_402.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_403.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_404.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_405.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_406.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_407.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_408.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_409.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_410.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_411.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_412.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_413.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_414.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_415.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_416.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_417.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_418.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_419.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_420.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_421.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_422.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_423.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_424.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_425.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_426.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_427.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_428.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_429.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_430.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_431.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_432.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_433.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_434.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_435.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_436.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_437.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_438.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_439.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_440.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_441.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_442.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_443.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_444.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_445.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_446.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_447.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_448.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_449.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_450.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_451.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_452.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_453.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_454.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_455.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_456.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_457.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_458.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_459.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_460.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_461.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_462.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_463.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_464.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_465.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_466.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_467.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_468.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_469.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_470.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_471.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_472.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_473.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_474.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_475.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_476.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_477.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_478.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_479.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_480.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_481.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_482.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_483.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_484.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_485.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_486.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_487.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_488.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_489.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_490.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_491.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_492.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_493.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_494.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_495.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_496.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_497.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_498.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_499.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_500.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_501.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_502.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_503.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_504.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_505.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_506.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_507.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_508.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_509.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_510.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_511.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_512.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_513.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_514.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_515.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_516.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_517.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_518.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_519.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_520.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_521.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_522.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_523.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_524.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_525.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_526.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_527.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_528.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_529.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_530.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_531.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_532.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_533.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_534.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_535.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_536.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_537.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_538.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_539.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_540.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_541.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_542.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_543.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_544.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_545.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_546.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_547.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_548.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_549.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_550.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_551.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_552.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_553.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_554.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_555.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_556.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_557.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_558.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_559.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_560.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_561.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_562.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_563.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_564.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_565.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_566.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_567.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_568.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_569.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_570.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_571.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_572.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_573.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_574.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_575.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_576.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_577.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_578.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_579.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_580.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_581.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_582.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_583.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_584.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_585.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_586.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_587.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_588.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_589.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_590.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_591.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_592.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_593.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_594.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_595.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_596.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_597.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_598.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_599.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_600.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_601.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_602.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_603.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_604.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_605.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_606.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_607.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_608.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_609.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_610.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_611.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_612.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_613.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_614.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_615.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_616.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_617.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_618.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_619.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_620.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_621.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_622.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_623.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_624.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_625.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_626.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_627.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_628.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_629.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_630.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_631.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_632.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_633.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_634.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_635.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_636.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_637.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_638.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_639.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_640.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_641.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_642.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_643.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_644.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_645.png has a NO GOAL
# ...
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1789.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1790.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1791.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1792.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1793.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1794.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1795.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1796.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1797.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1798.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1799.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1800.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1801.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1802.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1803.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1804.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1805.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1806.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1807.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1808.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1809.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1810.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1811.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1812.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1813.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1814.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1815.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1816.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1817.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1818.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1819.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1820.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1821.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1822.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1823.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1824.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1825.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1826.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1827.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1828.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1829.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1830.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1831.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1832.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1833.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1834.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1835.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1836.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1837.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1838.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1839.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1840.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1841.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1842.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1843.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1844.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1845.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1846.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1847.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1848.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1849.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1850.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1851.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1852.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1853.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1854.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1855.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1856.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1857.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1858.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1859.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1860.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1861.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1862.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1863.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1864.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1865.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1866.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1867.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1868.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1869.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1870.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1871.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1872.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1873.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1874.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1875.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1876.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1877.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1878.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1879.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1880.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1881.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1882.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1883.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1884.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1885.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1886.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1887.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1888.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1889.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1890.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1891.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1892.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1893.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1894.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1895.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1896.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1897.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1898.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1899.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1900.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1901.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1902.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1903.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1904.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1905.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1906.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1907.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1908.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1909.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1910.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1911.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1912.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1913.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1914.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1915.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1916.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1917.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1918.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1919.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1920.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1921.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1922.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1923.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1924.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1925.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1926.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1927.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1928.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1929.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1930.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1931.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1932.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1933.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1934.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1935.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1936.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1937.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1938.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1939.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1940.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1941.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1942.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1943.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1944.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1945.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1946.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1947.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1948.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1949.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1950.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1951.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1952.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1953.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1954.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1955.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1956.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1957.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1958.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1959.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1960.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1961.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1962.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1963.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1964.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1965.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1966.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1967.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1968.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1969.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1970.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1971.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1972.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1973.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1974.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1975.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1976.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1977.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1978.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1979.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1980.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1981.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1982.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1983.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1984.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1985.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1986.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1987.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1988.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1989.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1990.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1991.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1992.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1993.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1994.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1995.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1996.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1997.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1998.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1999.png has a NO GOAL

# %% [markdown]
# # Deep Learning - oriented solution
#
# The aim of this part is training a CNN on the dataset to predict if a goal is valid or not.
# Below there are shown libraries and functions used.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Training, Validation and Test set
#
# Since we want to use the entire dataset generated above as training set, the validation and the test set are here generated (under /content/drive/MyDrive/VISIOPE/validation/  and /content/drive/MyDrive/VISIOPE/test/  respectively).
#
# To do this we call the generate_dataset() function and the test() function twice to store images in the right folder.

# %%
val_path = '/content/drive/MyDrive/VISIOPE/val_set'
t_path = '/content/drive/MyDrive/VISIOPE/test_set'

validation_path = '/content/drive/MyDrive/VISIOPE/validation'
test_path = '/content/drive/MyDrive/VISIOPE/test'

# %%
n_val_img = generate_dataset(val_path)
n_test_img = generate_dataset(t_path)
# Out:
# Insert the number if images you want to generate for the dataset: 500
# Dataset generated. You can find the images in your Drive under  /content/drive/MyDrive/VISIOPE/val_set
# Insert the number if images you want to generate for the dataset: 100
# Dataset generated. You can find the images in your Drive under  /content/drive/MyDrive/VISIOPE/test_set

# %%
#test(n_val_img, src_path = val_path, dst_path = validation_path)
test(n_test_img, src_path = t_path, dst_path = test_path)
# Out:
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_0.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_1.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_2.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_3.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_4.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_5.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_6.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_7.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_8.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_9.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_10.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_11.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_12.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_13.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_14.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_15.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_16.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_17.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_18.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_19.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_20.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_21.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_22.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_23.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_24.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_25.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_26.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_27.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_28.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_29.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_30.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_31.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_32.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_33.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_34.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_35.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_36.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_37.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_38.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_39.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_40.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_41.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_42.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_43.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_44.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_45.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_46.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_47.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_48.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_49.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_50.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_51.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_52.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_53.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_54.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_55.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_56.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_57.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_58.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_59.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_60.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_61.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_62.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_63.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_64.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_65.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_66.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_67.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_68.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_69.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_70.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_71.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_72.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_73.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_74.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_75.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_76.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_77.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_78.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_79.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_80.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_81.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_82.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_83.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_84.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_85.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_86.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_87.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_88.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_89.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_90.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_91.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_92.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_93.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_94.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_95.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_96.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_97.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_98.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/test_set/img_99.png has a GOAL

# %% [markdown]
# # Labeling the dataset
#
# The function **test** seen above also writes in different folders Goal or No_Goal in the right path (training/validation/test) the images which represent a Goal or a No Goal respectively.

# %% [markdown]
# # CNN initizialization

# %% [markdown]
# With the **ImageDataGenerator** function we define the train and validation generator which allows us to:
#
# 1) Read images from the disk.
#
# 2) Decode contents of these images and convert it into proper grid format as per their RGB content.
#
# 3) Convert them into floating point tensors.
#
# 4) Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# Now, we can import from the right directory the data with **flow_from_directory** function. It also sets the batch_size and class_mode.
# For the training set we use a batch_size of 32 while for the validation set we use a batch_size of 16. Both of them has as class_mode the attribute binary, because the result of the cnn work is a binary classification: Goal, No Goal.

# %%
training_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/training/',
                                         target_size= (200,300),
                                         batch_size = 32,
                                         class_mode = 'binary')

validation_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/validation/',
                                         target_size= (200,300),
                                         batch_size = 16,
                                         class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# Labels:
#
#
# *   Goal: 0
# *   No_Goal: 1

# %%
training_set.class_indices
# Out:
# {'Goal': 0, 'No_Goal': 1}

# %% [markdown]
# # CNN structure

# %% [markdown]
# Below the structure of the CNN is shown. It has:
#
#
# *   **3 Convolutional Layers:** the filter is a 5x5 matrix and 16, 32 and 64 as dimensionality of the output space according to the first, second and third layer. Each convolutional operation is followed by an activation function (relu)
# *   **3 MaxPooling Layers**: they follow each convolutional layer and help in reducing the spatial dimensions. It's used a 2x2 matrix to store the max pool operation
# *   The **Flatten Layer** which flattens the input
# *   **2 Dense Layers**: the first one has 512 as units value, it means that 512 is the output dimensionality and uses relu as activation function; the second one has 1 as units value, it means that it produces a single output which represents the predicted label. Since this is a binary classification task the sigmoid function is used as activation.

# %%
model = tf.keras.models.Sequential( [tf.keras.layers.Conv2D(16, (5,5), activation = 'relu', input_shape = (200,300,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32, (5,5), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64, (5,5), activation ='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Flatten(),
                                    #
                                    tf.keras.layers.Dense(512, activation='relu'),
                                    #
                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                    ])

# %% [markdown]
# It's used as loss the binary cross entropy loss and Adam as optimizer. Learning rate is set to 0.001.

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics='accuracy')

# %% [markdown]
# To avoid inefficient computation time and space we use the Early Stopping method which stops the model process if the loss (in this case) doesn't decrement its value for 3 times.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %% [markdown]
# # Results

# %%
model_fit = model.fit(training_set, 
                      steps_per_epoch = 3,
                      epochs = 15,
                      callbacks=[callback],
                      validation_data = validation_set)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 34s 13s/step - loss: 0.3357 - accuracy: 0.8542 - val_loss: 0.4228 - val_accuracy: 0.8540
# Epoch 2/15
# 3/3 [==============================] - 35s 16s/step - loss: 0.3940 - accuracy: 0.8438 - val_loss: 0.2978 - val_accuracy: 0.8840
# Epoch 3/15
# 3/3 [==============================] - 34s 15s/step - loss: 0.3038 - accuracy: 0.8333 - val_loss: 0.3038 - val_accuracy: 0.8860
# Epoch 4/15
# 3/3 [==============================] - 34s 15s/step - loss: 0.1835 - accuracy: 0.9271 - val_loss: 0.3443 - val_accuracy: 0.8500
# Epoch 5/15
# 3/3 [==============================] - 32s 14s/step - loss: 0.3533 - accuracy: 0.8333 - val_loss: 0.2869 - val_accuracy: 0.8800
# Epoch 6/15
# 3/3 [==============================] - 34s 15s/step - loss: 0.2515 - accuracy: 0.9167 - val_loss: 0.3047 - val_accuracy: 0.8800
# Epoch 7/15
# 3/3 [==============================] - 33s 14s/step - loss: 0.2268 - accuracy: 0.9271 - val_loss: 0.2431 - val_accuracy: 0.8980

# %%
acc = model.history.history['accuracy']
val_accuracy = model.history.history["val_accuracy"]
plt.ylim(0,1)
plt.plot(acc, label="training accuracy")
plt.plot(val_accuracy, label="validation accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
loss = model.history.history["loss"]
val_loss = model.history.history["val_loss"]
plt.ylim(0,3)
plt.plot(loss, label="loss")
plt.plot(val_loss, label="validation loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
test_path = "/content/drive/MyDrive/VISIOPE/test_set"

img_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/Goal")
img_no_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/No_Goal")

dim_goal = len(img_goal)
dim_no_goal = len(img_no_goal)

goal = 0 
no_goal = 0

for i in os.listdir(test_path):
  img = image.load_img(test_path+"/"+str(i), target_size=(200,300,3))
  X = image.img_to_array(img)
  X = np.expand_dims(X, axis=0)
  images = np.vstack([X])
  val = model.predict(images)
  check_img = str(i) 
  if val == 0:
    if check_img in img_goal:
      goal += 1
  else:
    if check_img in img_no_goal:
      no_goal += 1
    
correct = goal+no_goal
total_dim = dim_goal+dim_no_goal

test_acc = correct/total_dim
goal_acc = goal/dim_goal
no_goal_acc = no_goal/dim_no_goal

print("Total accuracy: ", test_acc)
print("Goal accuracy: ", goal_acc)
print("No Goal accuracy: ", no_goal_acc)
# Out:
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# Total accuracy:  0.91
# Goal accuracy:  0.8867924528301887
# No Goal accuracy:  0.9361702127659575
