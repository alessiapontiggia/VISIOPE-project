# %% [markdown]
# <a href="https://colab.research.google.com/github/alessiapontiggia/VISIOPE-project/blob/main/proj_visiope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This paper shows the task I want to deal with: the goal line technology.
# Its aim is about deciding if a goal is valid or not (i.e. checking if the ball has entirly passed the goal line).
# To do this, there will be shown two techniques:
#
# *   Detections of the ball and the line to determine if that ball has passed that line.
# *  Learning with a CNN if a goal is valid or not from a dataset of images.

# %% [markdown]
# Utils 1: libreries and functions
# Below, you can see the libreries I import and the functions I use to develop the project. At each section, they are described in details.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import matplotlib.patheffects as path_effects
import random

# %%
def read_image(img_path):
  img = cv.imread(img_path)
  return img

# %%
def convert_bgr_to_rgb(img_bgr):
  img_rgb = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)
  return img_rgb

# %%
def show_image(img, title):
  plt.axis('off')
  plt.imshow(img)
  plt.title(title)
  return

# %%
def building_image():
  # random image dimensions
  y = random.randint(200, 250)
  x = random.randint(200, 250)
  img_shape = (y, x, 3)
  
  # random background color in the shape of a green pitch
  green = random.randint(150,255)
  red = random.randint(1,30)
  blue = random.randint(1,30)
  background_color = (red,green,blue)
  background = np.full(img_shape, background_color, dtype=np.uint8)
  
  # white line in a vertical plane (0) or horizontal plane (1) at random position
  choice = random.randint(0,1)
  match choice:
    case 0:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      x_line = random.randint(x_mean-50, x_mean+50)
      y_start = -1500
      y_end = 1500
      pt1 = (x_line, y_start)
      pt2 = (x_line, y_end)
      cv.line(background, pt1, pt2, line_color, 20)
    case 1:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      y_line = random.randint(y_mean-50, y_mean+50)
      x_start = -1500
      x_end = 1500
      pt1 = (x_start, y_line)
      pt2 = (x_end, y_line)
      cv.line(background, pt1, pt2, line_color, 20)
      

  # circle (ball) in a random position
  x_c = random.randint(x_mean-50, x_mean+50)
  y_c = random.randint(y_mean-50, y_mean+50)
  center_ball = (x_c, y_c)
  radius = random.randint(20, 25)
  ball_color = (200,200,200)
  cv.circle(background, center_ball, radius, ball_color, cv.FILLED)
  
  return background

# %%
def generate_dataset(n_img, data_path):
  for i in range(0, n_img):
    path = data_path+"/img_"+str(i)+".png"
    img = building_image()
    cv.imwrite(path, img)
  print("Dataset generated. You can find the images in your Drive under ", data_path)
  return

# %%
def ball_detection(original_img):
  img = original_img.copy()
  gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
  edges = cv.Canny(gray,100,200)
  circles = cv.HoughCircles(edges, cv.HOUGH_GRADIENT, 1, 20, param1 = 100,
               param2 = 20, minRadius = 0, maxRadius = 0)
  detected = original_img.copy()
  points = {}
  points["x"] = []
  points["y"] = []
  if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
      cv.circle(detected, (x, y), r, (255, 0, 0), 2)
      points["x"].append(x+r)
      points["x"].append(x-r)
      points["y"].append(y+r)
      points["y"].append(y-r)
    return points, detected
  else:
    print('No ball detected.\n')
    return

# %%
def ball_lines(img, extrema, h_or_v):
  shape = img.shape
  result = img.copy()
  ball_lines = []
  if extrema is not None:
    for key in extrema:
      match h_or_v:
        case 1:
          if key=="x":
            for value in extrema[key]:
              start = (value, -1500)
              end = (value, 1500)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
        case 0:
          if key=="y":
            for value in extrema[key]:
              start = (-1500, value)
              end = (1500, value)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
  else:
    print("No line projections of the ball because no ball was found.\n")
  return ball_lines, result

# %%
def line_detection(img):
  
  result = img.copy()
  gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
  canny = cv.Canny(gray, 100, 200)
  lines = cv.HoughLines(canny, 1, np.pi/180,  150, None, 0, 0)
  
  goal_lines = []
  if lines is not None:
    for i in range(0, len(lines)):
      rho = lines[i][0][0]
      theta = lines[i][0][1]
      a = np.cos(theta)
      b = np.sin(theta)
      x0 = a * rho
      y0 = b * rho
      pt1 = (int(x0 + 1500*(-b)), int(y0 + 1500*(a)))
      pt2 = (int(x0 - 1500*(-b)), int(y0 - 1500*(a)))
      cv.line(result, pt1, pt2, (0,0,255), 3, cv.LINE_AA)
      goal_lines.append(pt1)
      goal_lines.append(pt2)
    return goal_lines, result
  else:
    print("No Line Detected.\n")
    return [], result

# %%
def from_tuples_to_coordinates(tuples, val):
  result = []
  if tuples is not None and len(tuples)>0:
    for t in tuples:
      match val:
        case "x":
          result.append(t[0])
        case "y":
          result.append(t[1])
  return result

# %%
def horizontal_vertical_line(goal_lines, img):
  
  dim_x = img.shape[1]
  dim_y = img.shape[0]

  x = from_tuples_to_coordinates(goal_lines, val="x")
  y = from_tuples_to_coordinates(goal_lines, val="y")

  if len(x) > 0:
    max_x = max(x)
    if max_x > dim_x:
      return 0          # horizontal line
  
  if len(y) > 0:
    max_y = max(y)
    if max_y > dim_y:
      return 1          # vertical line
  
  return "No line was found"

# %%
def var_check(img, ball_lines, goal_lines):

  if len(ball_lines)==0:
    print("No ball was found\n")
    return
  if len(goal_lines)==0:
    print("No line was found\n")
    return 

  h_v = horizontal_vertical_line(goal_lines, img)
  match h_v: 
    case 0:
      ball_y_coordinates = from_tuples_to_coordinates(ball_lines, val="y")
      line_y_coordinates = from_tuples_to_coordinates(goal_lines, val="y")
      max_y_ball = max(ball_y_coordinates)
      min_y_ball = min(ball_y_coordinates)
      max_y_line = max(line_y_coordinates)
      min_y_line = min(line_y_coordinates)
      if min_y_ball > max_y_line or max_y_ball < min_y_line:
        return 1
      else:
        return 0 
    case 1:
      ball_x_coordinates = from_tuples_to_coordinates(ball_lines, val="x")
      line_x_coordinates = from_tuples_to_coordinates(goal_lines, val="x")
      max_x_ball = max(ball_x_coordinates)
      min_x_ball = min(ball_x_coordinates)
      max_x_line = max(line_x_coordinates)
      min_x_line = min(line_x_coordinates)
      if min_x_ball > max_x_line or max_x_ball < min_x_line:
        return 1
      else:
        return 0

# %%
def test(from_n, to_n, src_path, dst_path):
  
  for i in range(from_n, to_n):
    # reading and processing the image
    img_path = src_path+'/img_'+str(i)+".png"
    img = convert_bgr_to_rgb(read_image(img_path))
    # ball detection 
    points, img_ball_detected = ball_detection(img)
    # line detection
    goal_lines, img_line_detection = line_detection(img)
    # horizontal or vertical line
    h_or_v = horizontal_vertical_line(goal_lines, img)
    
    ball_line, img_ball_lines = ball_lines(img, points, h_or_v)
    g = var_check(img, ball_line, goal_lines)
    if g == 0:
      print("The image: "+str(img_path)+" has a NO GOAL")
      img_no_goal_path = dst_path+'/No_Goal/img_'+str(i)+".png"
      cv.imwrite(img_no_goal_path,img)
    elif g == 1:
      print("The image: "+str(img_path)+" has a GOAL")
      img_goal_path = dst_path+'/Goal/img_'+str(i)+".png"
      cv.imwrite(img_goal_path, img)
    else:
      print("The image: "+str(img_path)+" occured an error\n")
  return

# %% [markdown]
# # Building Dataset

# %% [markdown]
# To have a more various and a deeper set of images, unavailable online, I provide it by myself.
#
# The function **generate_dataset** calls n times the **building_image** function, where n is an input value and represents the size of the dataset (i.e. the number of images).
#
# The images generated are stored in /content/drive/MyDrive/VISIOPE/dataset path.
# These frames are made of 3 main parts:
#
#
# 1.   A green background: the pitch
# 2.   A filled circle: the ball
# 3.   A vertical or horizontal white line: the goal line
#
# Positions, dimensions and colors of these components are picked randomically.
#
# **Since the dataset is already generated and stored under the folder /content/drive/MyDrive/VISIOPE/dataset don't compile the code below (or compile it to generate a NEW dataset and wait some minutes to complete the operation)**

# %%
n_img = 5000

# %%
# DON'T COMPILE IF YOU DON'T WANT TO GENERATE ANOTHER DATASET (It already exists)
dataset_path = "/content/drive/MyDrive/VISIOPE/dataset"
generate_dataset(n_img, dataset_path)
# Out:
# Dataset generated. You can find the images in your Drive under  /content/drive/MyDrive/VISIOPE/dataset

# %%
len(os.listdir(dataset_path))
# Out:
# 5000

# %% [markdown]
# # Training, Validation, Test: sizesand paths

# %% [markdown]
# From the dataset made up of n_img = 3000 images, we build:
#
#
# *   Training set which size is 70% of n_img -> 2100 images
# *   Validation set which size is 20% of n_img -> 600 images
# *   Test set which size is 10% of n_img -> 300 images

# %%
training_size = int(0.8*n_img)
validation_size = int(0.1*n_img)
test_size = int(0.1*n_img)

training_path = '/content/drive/MyDrive/VISIOPE/training'
val_path = '/content/drive/MyDrive/VISIOPE/validation'
t_path = '/content/drive/MyDrive/VISIOPE/test'

# %% [markdown]
# # Computer Vision - oriented solution

# %% [markdown]
# Below it's shown an example on how the proposed solution works.

# %% [markdown]
# # Image Processing
#
# First thing to do is reading the input image. So we use the **read_image** and the **convert_bgr_to_rgb** functions to read and convert the image in the color space we want (RGB).
#
# Then we apply the Canny Edge Detector on the gray scale image, it will be used to have a clearer representation of the shapes.
#
# The input image, the gray scale image, and the Canny Edge image application are then shown with **show_image** function.

# %%
random_img_index = random.randint(0, n_img)
img_path = '/content/drive/MyDrive/VISIOPE/dataset/img_'+str(random_img_index)+".png"
img = convert_bgr_to_rgb(read_image(img_path))
show_image(img, title="input image")
img_shape = img.shape
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,100,200)

# %%
fig, axs = plt.subplots(1, 3)
plt.figure(figsize=(3,5))
axs[0].imshow(img)
axs[0].set_title('Input Image')
axs[1].imshow(gray)
axs[1].set_title('Gray Scale Image')
axs[2].imshow(edges)
axs[2].set_title('Edge Detector Applied')
# Out:
# Text(0.5, 1.0, 'Edge Detector Applied')

# %% [markdown]
# # Detection of the ball
#
# Since the ball has a circular shape, it's used the openCV **Hough Circles** algorithm to detect the ball in the **ball_detection** function.
# The function I implemented returns as first parameter a dictionary where the keys are coordinates (x and y), and the values are the 4 points (2 for the key "x" and the other 2 for the key "y") at the highest distance (radius) from the center of the circle. The second parameter returned by the ball detection function is a copy of the input image with the circle (ball) underlined.

# %%
points, img_ball_detected = ball_detection(img)
show_image(img_ball_detected, title="Ball detection")

# %% [markdown]
# # Goal line Detection
#
# To detect the goal line it's used the openCV algorithm **HoughLines** in the **line_detection** function.
#
# The goal line is made up of two lines (boundaries).
#
# So this function returns a list of the points through which the lines pass.

# %%
goal_lines, img_line_detection = line_detection(img)
show_image(img_line_detection, title="Line Detection")

# %% [markdown]
# # Goal Or No Goal?
#
# To understand if a goal is valid or not, I first check if:
# - the goal line is vertical
# - the goal line is horizontal

# %% [markdown]
# To understand if the goal line lies on a vertical or on a horizontal axis, I use the **horizontal_vertical_line** function that controls the value of the points through which the lines pass.
#
# This function returns 0 if the line is horizontal or 1 if the line is vertical.

# %%
h_or_v = horizontal_vertical_line(goal_lines, img)
if h_or_v == 0:
  print("Horizontal Line")
elif h_or_v == 1:
  print("Vertical Line")
else:
  print("No line detected...")
# Out:
# Vertical Line

# %% [markdown]
# Once I checked this, I focus on the vertical or horizontal line projections of the ball according to the vertical or horizontal axis of the goal line.

# %%
ball_line, img_ball_lines = ball_lines(img, points, h_or_v)
show_image(img_ball_lines, title="Projection lines of the ball")

# %% [markdown]
# Now, to see if the ball has entirly passed the goal line, I describe below the mechanism I used in the **goal_no_goal** function.
#
# *In the vertical case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the x axis)
#
# *In the horizontal case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball line coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the y axis)

# %%
val = var_check(img, ball_line, goal_lines)
if val == 1:
  print("GOAL")
elif val == 0:
  print("NO GOAL")
else:
  print("Something went wrong...")
# Out:
# NO GOAL

# %% [markdown]
# # Results (CV)
#
# Now we want to see the results on the entire dataset of the first method described above. This is done by the function **test**.

# %%
# DON'T COMPILE IF YOU DON'T WANT TO LABEL AGAIN THE IMAGES (They're already labeled and stored)
test(0, training_size, src_path = "/content/drive/MyDrive/VISIOPE/dataset", dst_path = "/content/drive/MyDrive/VISIOPE/training")
# Out:
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_0.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_3.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_5.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_6.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_7.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_8.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_9.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_10.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_11.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_12.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_13.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_14.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_15.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_16.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_17.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_18.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_19.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_20.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_21.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_22.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_23.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_24.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_25.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_26.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_27.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_28.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_29.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_30.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_31.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_32.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_33.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_34.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_35.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_36.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_37.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_38.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_39.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_40.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_41.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_42.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_43.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_44.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_45.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_46.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_47.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_48.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_49.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_50.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_51.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_52.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_53.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_54.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_55.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_56.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_57.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_58.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_59.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_60.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_61.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_62.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img
png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4716.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4717.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4718.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4719.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4720.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4721.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4722.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4723.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4724.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4725.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4726.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4727.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4728.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4729.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4730.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4731.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4732.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4733.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4734.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4735.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4736.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4737.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4738.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4739.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4740.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4741.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4742.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4743.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4744.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4745.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4746.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4747.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4748.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4749.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4750.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4751.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4752.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4753.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4754.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4755.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4756.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4757.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4758.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4759.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4760.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4761.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4762.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4763.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4764.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4765.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4766.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4767.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4768.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4769.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4770.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4771.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4772.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4773.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4774.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4775.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4776.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4777.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4778.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4779.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4780.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4781.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4782.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4783.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4784.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4785.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4786.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4787.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4788.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4789.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4790.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4791.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4792.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4793.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4794.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4795.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4796.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4797.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4798.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4799.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4800.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4801.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4802.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4803.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4804.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4805.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4806.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4807.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4808.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4809.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4810.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4811.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4812.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4813.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4814.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4815.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4816.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4817.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4818.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4819.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4820.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4821.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4822.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4823.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4824.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4825.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4826.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4827.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4828.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4829.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4830.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4831.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4832.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4833.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4834.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4835.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4836.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4837.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4838.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4839.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4840.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4841.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4842.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4843.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4844.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4845.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4846.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4847.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4848.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4849.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4850.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4851.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4852.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4853.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4854.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4855.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4856.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4857.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4858.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4859.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4860.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4861.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4862.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4863.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4864.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4865.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4866.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4867.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4868.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4869.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4870.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4871.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4872.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4873.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4874.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4875.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4876.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4877.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4878.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4879.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4880.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4881.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4882.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4883.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4884.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4885.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4886.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4887.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4888.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4889.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4890.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4891.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4892.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4893.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4894.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4895.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4896.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4897.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4898.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4899.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4900.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4901.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4902.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4903.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4904.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4905.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4906.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4907.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4908.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4909.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4910.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4911.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4912.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4913.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4914.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4915.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4916.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4917.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4918.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4919.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4920.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4921.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4922.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4923.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4924.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4925.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4926.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4927.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4928.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4929.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4930.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4931.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4932.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4933.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4934.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4935.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4936.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4937.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4938.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4939.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4940.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4941.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4942.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4943.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4944.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4945.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4946.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4947.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4948.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4949.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4950.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4951.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4952.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4953.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4954.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4955.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4956.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4957.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4958.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4959.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4960.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4961.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4962.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4963.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4964.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4965.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4966.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4967.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4968.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4969.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4970.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4971.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4972.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4973.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4974.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4975.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4976.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4977.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4978.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4979.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4980.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4981.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4982.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4983.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4984.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4985.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4986.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4987.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4988.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4989.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4990.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4991.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4992.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4993.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4994.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4995.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4996.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4997.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4998.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4999.png has a GOAL

# %% [markdown]
# # Deep Learning - oriented solution
#
# The aim of this part is training a CNN on the dataset to predict if a goal is valid or not.
# Below there are shown libraries and functions used.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# # Labeling the dataset
#
# The function **test** seen above also writes in different folders Goal or No_Goal in the right path (training/validation/test) the images which represent a Goal or a No Goal respectively.

# %% [markdown]
# # Data Augmentation
#
# In order to:
#
# *  increase the model's ability to generalize
# *  add variability to the data and minimizes data overfitting
# *  save on the cost of collecting and labeling additional data
# *  improve the accuracy of the deep learning model's predictions
#
# the data augmentation technique is used.
#
# For our case of study FLIPS, CROPS, SATURATION and BRIGHTNESS are applied.

# %%
def augmentation(path, starter, technique):
  goal_path = path+str('/Goal')
  no_goal_path = path+str('/No_Goal')

  goals = os.listdir(goal_path)
  no_goals = os.listdir(no_goal_path)

  dim_goals = len(goals)
  dim_no_goals = len(no_goals)
  total_dim = dim_goals+dim_no_goals

  src_goal_images = []
  src_no_goal_images = []
  n_src = 125
  
  for i in range(0,n_src):
    index_goal = random.randint(0, dim_goals)
    index_no_goal = random.randint(0, dim_no_goals)
    src_goal_images.append(goals[index_goal])
    src_no_goal_images.append(no_goals[index_no_goal])
  
  for i in range(0, len(src_goal_images)):
    match technique:
      case "FLIP":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.flip_left_right(img)
        new_img = np.squeeze(t)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        cv.imwrite(new_img_path, new_img)
      case "BRIGHTNESS":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        t = tf.image.adjust_brightness(img, delta=0.1)
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "SATURATION":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.adjust_saturation(img, 0.5)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "CROP":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.central_crop(img, 0.5)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)

  for i in range(0, len(src_no_goal_images)):
    match technique:
      case "FLIP":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.flip_left_right(img)
        new_img = np.squeeze(t)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        cv.imwrite(new_img_path, new_img)
      case "BRIGHTNESS":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        t = tf.image.adjust_brightness(img, delta=0.1)
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "SATURATION":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.adjust_saturation(img, 0.5)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "CROP":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.central_crop(img, 0.5)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
  return

# %%
size = len(os.listdir(training_path+str('/Goal/')))+len(os.listdir(training_path+str('/No_Goal/')))
techniques = ["FLIP", "BRIGHTNESS", "SATURATION", "CROP"]

for technique in techniques:
  augmentation(training_path, size, technique)

# %% [markdown]
# # Data Distribution

# %% [markdown]
# Training Data distribution:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/training/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/training/No_Goal"))
print("Goals found: ", goals)
print("No Goals found: ", no_goals)
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="green")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Goals found:  2259
# No Goals found:  2741

# %% [markdown]
# Validation Data Distribution:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/validation/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/validation/No_Goal"))
print("Validation distribution data.\nGoals: "+str(goals)+"\nNo Goals: "+str(no_goals))
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="blue")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Validation distribution data.
# Goals: 230
# No Goals: 270

# %% [markdown]
# **Test Data Distribution**:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/test/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/test/No_Goal"))
print("Test distribution data.\nGoals: "+str(goals)+"\nNo Goals: "+str(no_goals))
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="red")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Test distribution data.
# Goals: 234
# No Goals: 266

# %% [markdown]
# # CNN initizialization

# %% [markdown]
# With the **ImageDataGenerator** function we define the train and validation generator which allows us to:
#
# 1) Read images from the disk.
#
# 2) Decode contents of these images and convert it into proper grid format as per their RGB content.
#
# 3) Convert them into floating point tensors.
#
# 4) Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# Now, we can import from the right directory the data with **flow_from_directory** function. It also sets the batch_size and class_mode.
# For the training set we use a batch_size of 128 while for the validation set we use a batch_size of 32. Both of them has as class_mode the attribute binary, because the result of the cnn work is a binary classification: Goal, No Goal.

# %%
training_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/training/',
                                         target_size= (200,200),
                                         batch_size = 128,
                                         class_mode = 'binary')

validation_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/validation/',
                                         target_size= (200,200),
                                         batch_size = 64,
                                         class_mode = 'binary')
# Out:
# Found 5000 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.

# %% [markdown]
# Labels:
#
#
# *   Goal: 0
# *   No_Goal: 1

# %%
training_set.class_indices
# Out:
# {'Goal': 0, 'No_Goal': 1}

# %% [markdown]
# # CNN structure

# %% [markdown]
# Below the structure of the CNN is shown. It has:
#
#
# *   **3 Convolutional Layers:** the filter is a 5x5 matrix and 16, 32 and 64 as dimensionality of the output space according to the first, second and third layer. Each convolutional operation is followed by an activation function (relu)
# *   **3 MaxPooling Layers**: they follow each convolutional layer and help in reducing the spatial dimensions. It's used a 2x2 matrix to store the max pool operation
# *   The **Flatten Layer** converts the multi-dimensional image data array to 1D array
# *   **2 Dense Layers**: the first one has 512 as units value, it means that 512 is the output dimensionality and uses relu as activation function; the second one has 1 as units value, it means that it produces a single output which represents the predicted label. Since this is a binary classification task the sigmoid function is used as activation.

# %%
model = tf.keras.models.Sequential( [tf.keras.layers.Conv2D(16, (5,5), activation = 'relu', input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32, (5,5), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64, (5,5), activation ='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Flatten(),
                                    #
                                    tf.keras.layers.Dense(512, activation='relu'),
                                    #
                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                    ])

# %% [markdown]
# It's used as loss the binary cross entropy loss and Adam as optimizer. Learning rate is set to 0.001.

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics='accuracy')

# %% [markdown]
# To avoid inefficient computation time and space we use the Early Stopping method which stops the model process if the loss (in this case) doesn't decrement its value for 3 times.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %% [markdown]
# # Results (DL)

# %%
model_fit = model.fit(training_set, 
                      steps_per_epoch = 3,
                      epochs = 20,
                      callbacks=[callback],
                      validation_data = validation_set)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 64s 25s/step - loss: 1.3818 - accuracy: 0.4740 - val_loss: 0.7846 - val_accuracy: 0.4600
# Epoch 2/20
# 3/3 [==============================] - 56s 22s/step - loss: 0.7369 - accuracy: 0.4792 - val_loss: 0.6896 - val_accuracy: 0.5680
# Epoch 3/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.6889 - accuracy: 0.5781 - val_loss: 0.6801 - val_accuracy: 0.6120
# Epoch 4/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.6799 - accuracy: 0.6016 - val_loss: 0.6574 - val_accuracy: 0.6120
# Epoch 5/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.6554 - accuracy: 0.6276 - val_loss: 0.6422 - val_accuracy: 0.6280
# Epoch 6/20
# 3/3 [==============================] - 55s 22s/step - loss: 0.6727 - accuracy: 0.5964 - val_loss: 0.6453 - val_accuracy: 0.6280
# Epoch 7/20
# 3/3 [==============================] - 56s 22s/step - loss: 0.6283 - accuracy: 0.6823 - val_loss: 0.6327 - val_accuracy: 0.6560
# Epoch 8/20
# 3/3 [==============================] - 55s 21s/step - loss: 0.6193 - accuracy: 0.6562 - val_loss: 0.6001 - val_accuracy: 0.6760
# Epoch 9/20
# 3/3 [==============================] - 46s 17s/step - loss: 0.5818 - accuracy: 0.6818 - val_loss: 0.5530 - val_accuracy: 0.7380
# Epoch 10/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.5469 - accuracy: 0.7630 - val_loss: 0.4957 - val_accuracy: 0.7980
# Epoch 11/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.5214 - accuracy: 0.7708 - val_loss: 0.3914 - val_accuracy: 0.8340
# Epoch 12/20
# 3/3 [==============================] - 56s 22s/step - loss: 0.4256 - accuracy: 0.8307 - val_loss: 0.3418 - val_accuracy: 0.8520
# Epoch 13/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.3715 - accuracy: 0.8516 - val_loss: 0.4917 - val_accuracy: 0.7820
# Epoch 14/20
# 3/3 [==============================] - 47s 17s/step - loss: 0.4363 - accuracy: 0.8177 - val_loss: 0.3581 - val_accuracy: 0.8480
# Epoch 15/20
# 3/3 [==============================] - 46s 17s/step - loss: 0.4133 - accuracy: 0.8646 - val_loss: 0.3019 - val_accuracy: 0.8880
# Epoch 16/20
# 3/3 [==============================] - 47s 17s/step - loss: 0.4130 - accuracy: 0.8229 - val_loss: 0.3819 - val_accuracy: 0.8240
# Epoch 17/20
# 3/3 [==============================] - 55s 21s/step - loss: 0.4055 - accuracy: 0.8333 - val_loss: 0.3375 - val_accuracy: 0.9000
# Epoch 18/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.3528 - accuracy: 0.8932 - val_loss: 0.2916 - val_accuracy: 0.9040
# Epoch 19/20
# 3/3 [==============================] - 54s 21s/step - loss: 0.3583 - accuracy: 0.8802 - val_loss: 0.2876 - val_accuracy: 0.8940
# Epoch 20/20
# 3/3 [==============================] - 54s 22s/step - loss: 0.3860 - accuracy: 0.8698 - val_loss: 0.2439 - val_accuracy: 0.9080

# %%
acc = model.history.history['accuracy']
val_accuracy = model.history.history["val_accuracy"]
plt.ylim(0,1)
plt.plot(acc, label="training accuracy")
plt.plot(val_accuracy, label="validation accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
loss = model.history.history["loss"]
val_loss = model.history.history["val_loss"]
plt.ylim(0,3)
plt.plot(loss, label="training loss")
plt.plot(val_loss, label="validation loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
def network_test():
  
  goal_path = "/content/drive/MyDrive/VISIOPE/test/Goal"
  no_goal_path = "/content/drive/MyDrive/VISIOPE/test/No_Goal"

  img_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/Goal")
  img_no_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/No_Goal")

  dim_goal = len(img_goal)
  dim_no_goal = len(img_no_goal)

  TP = 0
  TN = 0
  FP = 0
  FN = 0

  for i in os.listdir(goal_path):
    img = image.load_img(goal_path+"/"+str(i), target_size=(200,200,3))
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
      TP+=1
    else:
      FP+=1

  for i in os.listdir(no_goal_path):
    img = image.load_img(no_goal_path+"/"+str(i), target_size=(200,200,3))
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
      FN += 1
    else:
      TN += 1

  correct = TP+TN
  total_dim = dim_goal+dim_no_goal

  test_acc = correct/total_dim
  
  return test_acc, TP, TN, FP, FN

# %%
acc, TP, TN, FP, FN = network_test()
# Out:
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 74ms/step

# %% [markdown]
# Defining as:
#
#
# *   TP (true positive): Goals correctly classified as Goals
# *   TN (true negative): No Goals correctly classified as No Goals
# *   FP (false positive): No Goals wrongly classified as Goals
# *   FN (false negative): Goals wrongly classified as No Goals
#
# Let's print a bar with those values which are returned by the **network_test** function:

# %%
print("Test accuracy: ", acc)
y = [TP, FP, TN, FN]
x = ['TP', 'FP', 'TN', 'FN']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color=["blue", "red", "green", "orange"])
plt.title('Metrics')
plt.show()
# Out:
# Test accuracy:  0.914
