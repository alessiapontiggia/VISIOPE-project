# %% [markdown]
# <a href="https://colab.research.google.com/github/alessiapontiggia/VISIOPE-project/blob/main/proj_visiope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# This paper shows the task I want to deal with: the goal line technology.
# Its aim is about deciding if a goal is valid or not (i.e. checking if the ball has entirly passed the goal line).
# To do this, there will be shown two techniques:
#
# *   Detections of the ball and the line to determine if that ball has passed that line.
# *  Learning with a CNN if a goal is valid or not from a dataset of images.

# %% [markdown]
# Utils 1: libreries and functions
# Below, you can see the libreries I import and the functions I use to develop the project. At each section, they are described in details.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from matplotlib.colors import hsv_to_rgb
import matplotlib.patheffects as path_effects
import random

# %%
def read_image(img_path):
  img = cv.imread(img_path)
  return img

# %%
def convert_bgr_to_rgb(img_bgr):
  img_rgb = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)
  return img_rgb

# %%
def show_image(img, title):
  plt.axis('off')
  plt.imshow(img)
  plt.title(title)
  return

# %%
def building_image():
  # random image dimensions
  y = random.randint(200, 250)
  x = random.randint(200, 250)
  img_shape = (y, x, 3)
  
  # random background color in the shape of a green pitch
  green = random.randint(150,255)
  red = random.randint(1,30)
  blue = random.randint(1,30)
  background_color = (red,green,blue)
  background = np.full(img_shape, background_color, dtype=np.uint8)
  
  # white line in a vertical plane (0) or horizontal plane (1) at random position
  choice = random.randint(0,1)
  match choice:
    case 0:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      x_line = random.randint(x_mean-50, x_mean+50)
      y_start = -1500
      y_end = 1500
      pt1 = (x_line, y_start)
      pt2 = (x_line, y_end)
      cv.line(background, pt1, pt2, line_color, 20)
    case 1:
      line_color = (255, 255, 255)
      x_mean = int(img_shape[1]/2)      
      y_mean = int(img_shape[0]/2)
      y_line = random.randint(y_mean-50, y_mean+50)
      x_start = -1500
      x_end = 1500
      pt1 = (x_start, y_line)
      pt2 = (x_end, y_line)
      cv.line(background, pt1, pt2, line_color, 20)
      

  # circle (ball) in a random position
  x_c = random.randint(x_mean-50, x_mean+50)
  y_c = random.randint(y_mean-50, y_mean+50)
  center_ball = (x_c, y_c)
  radius = random.randint(20, 25)
  ball_color = (200,200,200)
  cv.circle(background, center_ball, radius, ball_color, cv.FILLED)
  
  return background

# %%
def generate_dataset(n_img, data_path):
  for i in range(0, n_img):
    path = data_path+"/img_"+str(i)+".png"
    img = building_image()
    cv.imwrite(path, img)
  print("Dataset generated. You can find the images in your Drive under ", data_path)
  return

# %%
def ball_detection(original_img):
  img = original_img.copy()
  gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
  edges = cv.Canny(gray,100,200)
  circles = cv.HoughCircles(edges, cv.HOUGH_GRADIENT, 1, 20, param1 = 100,
               param2 = 20, minRadius = 0, maxRadius = 0)
  detected = original_img.copy()
  points = {}
  points["x"] = []
  points["y"] = []
  if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
      cv.circle(detected, (x, y), r, (255, 0, 0), 2)
      points["x"].append(x+r)
      points["x"].append(x-r)
      points["y"].append(y+r)
      points["y"].append(y-r)
    return points, detected
  else:
    print('No ball detected.\n')
    return

# %%
def ball_lines(img, extrema, h_or_v):
  shape = img.shape
  result = img.copy()
  ball_lines = []
  if extrema is not None:
    for key in extrema:
      match h_or_v:
        case 1:
          if key=="x":
            for value in extrema[key]:
              start = (value, -1500)
              end = (value, 1500)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
        case 0:
          if key=="y":
            for value in extrema[key]:
              start = (-1500, value)
              end = (1500, value)
              cv.line(result, start, end, (255,0,0), 3, cv.LINE_AA)
              ball_lines.append(start)
              ball_lines.append(end)
  else:
    print("No line projections of the ball because no ball was found.\n")
  return ball_lines, result

# %%
def line_detection(img):
  
  result = img.copy()
  gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
  canny = cv.Canny(gray, 100, 200)
  lines = cv.HoughLines(canny, 1, np.pi/180,  150, None, 0, 0)
  
  goal_lines = []
  if lines is not None:
    for i in range(0, len(lines)):
      rho = lines[i][0][0]
      theta = lines[i][0][1]
      a = np.cos(theta)
      b = np.sin(theta)
      x0 = a * rho
      y0 = b * rho
      pt1 = (int(x0 + 1500*(-b)), int(y0 + 1500*(a)))
      pt2 = (int(x0 - 1500*(-b)), int(y0 - 1500*(a)))
      cv.line(result, pt1, pt2, (0,0,255), 3, cv.LINE_AA)
      goal_lines.append(pt1)
      goal_lines.append(pt2)
    return goal_lines, result
  else:
    print("No Line Detected.\n")
    return [], result

# %%
def from_tuples_to_coordinates(tuples, val):
  result = []
  if tuples is not None and len(tuples)>0:
    for t in tuples:
      match val:
        case "x":
          result.append(t[0])
        case "y":
          result.append(t[1])
  return result

# %%
def horizontal_vertical_line(goal_lines, img):
  
  dim_x = img.shape[1]
  dim_y = img.shape[0]

  x = from_tuples_to_coordinates(goal_lines, val="x")
  y = from_tuples_to_coordinates(goal_lines, val="y")

  if len(x) > 0:
    max_x = max(x)
    if max_x > dim_x:
      return 0          # horizontal line
  
  if len(y) > 0:
    max_y = max(y)
    if max_y > dim_y:
      return 1          # vertical line
  
  return "No line was found"

# %%
def var_check(img, ball_lines, goal_lines):

  if len(ball_lines)==0:
    print("No ball was found\n")
    return
  if len(goal_lines)==0:
    print("No line was found\n")
    return 

  h_v = horizontal_vertical_line(goal_lines, img)
  match h_v: 
    case 0:
      ball_y_coordinates = from_tuples_to_coordinates(ball_lines, val="y")
      line_y_coordinates = from_tuples_to_coordinates(goal_lines, val="y")
      max_y_ball = max(ball_y_coordinates)
      min_y_ball = min(ball_y_coordinates)
      max_y_line = max(line_y_coordinates)
      min_y_line = min(line_y_coordinates)
      if min_y_ball > max_y_line or max_y_ball < min_y_line:
        return 1
      else:
        return 0 
    case 1:
      ball_x_coordinates = from_tuples_to_coordinates(ball_lines, val="x")
      line_x_coordinates = from_tuples_to_coordinates(goal_lines, val="x")
      max_x_ball = max(ball_x_coordinates)
      min_x_ball = min(ball_x_coordinates)
      max_x_line = max(line_x_coordinates)
      min_x_line = min(line_x_coordinates)
      if min_x_ball > max_x_line or max_x_ball < min_x_line:
        return 1
      else:
        return 0

# %%
def test(from_n, to_n, src_path, dst_path):
  
  for i in range(from_n, to_n):
    # reading and processing the image
    img_path = src_path+'/img_'+str(i)+".png"
    img = convert_bgr_to_rgb(read_image(img_path))
    # ball detection 
    points, img_ball_detected = ball_detection(img)
    # line detection
    goal_lines, img_line_detection = line_detection(img)
    # horizontal or vertical line
    h_or_v = horizontal_vertical_line(goal_lines, img)
    
    ball_line, img_ball_lines = ball_lines(img, points, h_or_v)
    g = var_check(img, ball_line, goal_lines)
    if g == 0:
      print("The image: "+str(img_path)+" has a NO GOAL")
      img_no_goal_path = dst_path+'/No_Goal/img_'+str(i)+".png"
      cv.imwrite(img_no_goal_path,img)
    elif g == 1:
      print("The image: "+str(img_path)+" has a GOAL")
      img_goal_path = dst_path+'/Goal/img_'+str(i)+".png"
      cv.imwrite(img_goal_path, img)
    else:
      print("The image: "+str(img_path)+" occured an error\n")
  return

# %% [markdown]
# # Building Dataset

# %% [markdown]
# To have a more various and a deeper set of images, unavailable online, I provide it by myself.
#
# The function **generate_dataset** calls n times the **building_image** function, where n is an input value and represents the size of the dataset (i.e. the number of images).
#
# The images generated are stored in /content/drive/MyDrive/VISIOPE/dataset path.
# These frames are made of 3 main parts:
#
#
# 1.   A green background: the pitch
# 2.   A filled circle: the ball
# 3.   A vertical or horizontal white line: the goal line
#
# Positions, dimensions and colors of these components are picked randomically.
#
# **Since the dataset is already generated and stored under the folder /content/drive/MyDrive/VISIOPE/dataset don't compile the code below (or compile it to generate a NEW dataset and wait some minutes to complete the operation)**

# %%
n_img = 3000

# %%
# DON'T COMPILE IF YOU DON'T WANT TO GENERATE ANOTHER DATASET (It already exist)
dataset_path = "/content/drive/MyDrive/VISIOPE/dataset"
generate_dataset(n_img, dataset_path)
# Out:
# Dataset generated. You can find the images in your Drive under  /content/drive/MyDrive/VISIOPE/dataset

# %% [markdown]
# # Training, Validation, Test: sizesand paths

# %% [markdown]
# From the dataset made up of n_img = 3000 images, we build:
#
#
# *   Training set which size is 70% of n_img -> 2100 images
# *   Validation set which size is 20% of n_img -> 600 images
# *   Test set which size is 10% of n_img -> 300 images

# %%
training_size = int(0.7*n_img)
validation_size = int(0.2*n_img)
test_size = int(0.1*n_img)

training_path = '/content/drive/MyDrive/VISIOPE/training'
val_path = '/content/drive/MyDrive/VISIOPE/validation'
t_path = '/content/drive/MyDrive/VISIOPE/test'

# %% [markdown]
# # Computer Vision - oriented solution

# %% [markdown]
# Below it's shown an example on how the proposed solution works.

# %% [markdown]
# # Image Processing
#
# First thing to do is reading the input image. So we use the **read_image** and the **convert_bgr_to_rgb** functions to read and convert the image in the color space we want (RGB).
#
# Then we apply the Canny Edge Detector on the gray scale image, it will be used to have a clearer representation of the shapes.
#
# The input image, the gray scale image, and the Canny Edge image application are then shown with **show_image** function.

# %%
random_img_index = random.randint(0, n_img)
img_path = '/content/drive/MyDrive/VISIOPE/dataset/img_'+str(random_img_index)+".png"
img = convert_bgr_to_rgb(read_image(img_path))
show_image(img, title="input image")
img_shape = img.shape
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,100,200)

# %%
fig, axs = plt.subplots(1, 3)
plt.figure(figsize=(3,5))
axs[0].imshow(img)
axs[0].set_title('Input Image')
axs[1].imshow(gray)
axs[1].set_title('Gray Scale Image')
axs[2].imshow(edges)
axs[2].set_title('Edge Detector Applied')
# Out:
# Text(0.5, 1.0, 'Edge Detector Applied')

# %% [markdown]
# # Detection of the ball
#
# Since the ball has a circular shape, it's used the openCV **Hough Circles** algorithm to detect the ball in the **ball_detection** function.
# The function I implemented returns as first parameter a dictionary where the keys are coordinates (x and y), and the values are the 4 points (2 for the key "x" and the other 2 for the key "y") at the highest distance (radius) from the center of the circle. The second parameter returned by the ball detection function is a copy of the input image with the circle (ball) underlined.

# %%
points, img_ball_detected = ball_detection(img)
show_image(img_ball_detected, title="Ball detection")

# %% [markdown]
# # Goal line Detection
#
# To detect the goal line it's used the openCV algorithm **HoughLines** in the **line_detection** function.
#
# The goal line is made up of two lines (boundaries).
#
# So this function returns a list of the points through which the lines pass.

# %%
goal_lines, img_line_detection = line_detection(img)
show_image(img_line_detection, title="Line Detection")

# %% [markdown]
# # Goal Or No Goal?
#
# To understand if a goal is valid or not, I first check if:
# - the goal line is vertical
# - the goal line is horizontal

# %% [markdown]
# To understand if the goal line lies on a vertical or on a horizontal axis, I use the **horizontal_vertical_line** function that controls the value of the points through which the lines pass.
#
# This function returns 0 if the line is horizontal or 1 if the line is vertical.

# %%
h_or_v = horizontal_vertical_line(goal_lines, img)
if h_or_v == 0:
  print("Horizontal Line")
elif h_or_v == 1:
  print("Vertical Line")
else:
  print("No line detected...")
# Out:
# Horizontal Line

# %% [markdown]
# Once I checked this, I focus on the vertical or horizontal line projections of the ball according to the vertical or horizontal axis of the goal line.

# %%
ball_line, img_ball_lines = ball_lines(img, points, h_or_v)
show_image(img_ball_lines, title="Projection lines of the ball")

# %% [markdown]
# Now, to see if the ball has entirly passed the goal line, I describe below the mechanism I used in the **goal_no_goal** function.
#
# *In the vertical case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the x axis)
#
# *In the horizontal case*, the goal is valid iff:
# - the minimum ball coordinate is bigger than the maximum goal line coordinate OR the maximum ball line coordinate is smaller than the minimum goal line coordinate.
# (These coordinates belong to the y axis)

# %%
val = var_check(img, ball_line, goal_lines)
if val == 1:
  print("GOAL")
elif val == 0:
  print("NO GOAL")
else:
  print("Something went wrong...")
# Out:
# GOAL

# %% [markdown]
# # Results (CV)
#
# Now we want to see the results on the entire dataset of the first method described above. This is done by the function **test**.
#
# **Since this method stores the images in different folders to create labels for the CNN, which is already done, don't compile it (or compile it and wait for some minutes to complete the operation).**

# %%
# DON'T COMPILE IF YOU DON'T WANT TO LABEL AGAIN THE IMAGES (They're already labeled and stored)
test(0, training_size, src_path = "/content/drive/MyDrive/VISIOPE/dataset", dst_path = "/content/drive/MyDrive/VISIOPE/training")
# Out:
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_0.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_1.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_3.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_4.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_5.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_6.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img
png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2713.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2714.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2715.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2716.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2717.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2718.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2719.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2720.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2721.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2722.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2723.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2724.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2725.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2726.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2727.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2728.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2729.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2730.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2731.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2732.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2733.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2734.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2735.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2736.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2737.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2738.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2739.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2740.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2741.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2742.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2743.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2744.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2745.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2746.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2747.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2748.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2749.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2750.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2751.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2752.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2753.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2754.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2755.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2756.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2757.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2758.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2759.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2760.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2761.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2762.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2763.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2764.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2765.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2766.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2767.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2768.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2769.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2770.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2771.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2772.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2773.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2774.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2775.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2776.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2777.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2778.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2779.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2780.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2781.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2782.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2783.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2784.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2785.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2786.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2787.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2788.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2789.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2790.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2791.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2792.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2793.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2794.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2795.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2796.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2797.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2798.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2799.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2800.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2801.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2802.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2803.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2804.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2805.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2806.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2807.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2808.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2809.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2810.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2811.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2812.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2813.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2814.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2815.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2816.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2817.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2818.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2819.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2820.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2821.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2822.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2823.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2824.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2825.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2826.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2827.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2828.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2829.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2830.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2831.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2832.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2833.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2834.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2835.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2836.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2837.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2838.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2839.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2840.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2841.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2842.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2843.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2844.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2845.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2846.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2847.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2848.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2849.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2850.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2851.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2852.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2853.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2854.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2855.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2856.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2857.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2858.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2859.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2860.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2861.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2862.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2863.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2864.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2865.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2866.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2867.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2868.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2869.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2870.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2871.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2872.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2873.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2874.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2875.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2876.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2877.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2878.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2879.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2880.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2881.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2882.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2883.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2884.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2885.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2886.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2887.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2888.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2889.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2890.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2891.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2892.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2893.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2894.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2895.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2896.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2897.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2898.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2899.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2900.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2901.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2902.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2903.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2904.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2905.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2906.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2907.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2908.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2909.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2910.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2911.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2912.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2913.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2914.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2915.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2916.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2917.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2918.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2919.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2920.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2921.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2922.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2923.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2924.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2925.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2926.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2927.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2928.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2929.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2930.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2931.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2932.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2933.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2934.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2935.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2936.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2937.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2938.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2939.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2940.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2941.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2942.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2943.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2944.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2945.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2946.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2947.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2948.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2949.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2950.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2951.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2952.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2953.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2954.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2955.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2956.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2957.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2958.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2959.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2960.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2961.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2962.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2963.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2964.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2965.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2966.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2967.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2968.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2969.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2970.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2971.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2972.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2973.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2974.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2975.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2976.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2977.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2978.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2979.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2980.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2981.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2982.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2983.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2984.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2985.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2986.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2987.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2988.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2989.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2990.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2991.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2992.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2993.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2994.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2995.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2996.png has a GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2997.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2998.png has a NO GOAL
# The image: /content/drive/MyDrive/VISIOPE/dataset/img_2999.png has a NO GOAL

# %% [markdown]
# # Deep Learning - oriented solution
#
# The aim of this part is training a CNN on the dataset to predict if a goal is valid or not.
# Below there are shown libraries and functions used.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# # Labeling the dataset
#
# The function **test** seen above also writes in different folders Goal or No_Goal in the right path (training/validation/test) the images which represent a Goal or a No Goal respectively.

# %% [markdown]
# # Data Augmentation
#
# In order to:
#
# *  increase the model's ability to generalize
# *  add variability to the data and minimizes data overfitting
# *  save on the cost of collecting and labeling additional data
# *  improve the accuracy of the deep learning model's predictions
#
# the data augmentation technique is used.
#
# For our case of study FLIPS, CROPS, SATURATION and BRIGHTNESS are applied.

# %%
def augmentation(path, starter, technique):
  goal_path = path+str('/Goal')
  no_goal_path = path+str('/No_Goal')

  goals = os.listdir(goal_path)
  no_goals = os.listdir(no_goal_path)

  dim_goals = len(goals)
  dim_no_goals = len(no_goals)
  total_dim = dim_goals+dim_no_goals

  src_goal_images = []
  src_no_goal_images = []
  n_src = 50
  
  for i in range(0,n_src):
    index_goal = random.randint(0, dim_goals)
    index_no_goal = random.randint(0, dim_no_goals)
    src_goal_images.append(goals[index_goal])
    src_no_goal_images.append(no_goals[index_no_goal])
  
  for i in range(0, len(src_goal_images)):
    match technique:
      case "FLIP":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.flip_left_right(img)
        new_img = np.squeeze(t)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        cv.imwrite(new_img_path, new_img)
      case "BRIGHTNESS":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        t = tf.image.adjust_brightness(img, delta=0.1)
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "SATURATION":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.adjust_saturation(img, 0.5)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "CROP":
        img = image.load_img(goal_path+"/"+str(src_goal_images[i]))
        t = tf.image.central_crop(img, 0.5)
        new_img_path = goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)

  for i in range(0, len(src_no_goal_images)):
    match technique:
      case "FLIP":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.flip_left_right(img)
        new_img = np.squeeze(t)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        cv.imwrite(new_img_path, new_img)
      case "BRIGHTNESS":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        t = tf.image.adjust_brightness(img, delta=0.1)
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "SATURATION":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.adjust_saturation(img, 0.5)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
      case "CROP":
        img = image.load_img(no_goal_path+"/"+str(src_no_goal_images[i]))
        t = tf.image.central_crop(img, 0.5)
        new_img_path = no_goal_path+str('/img_')+str(starter+i)+str('.png')
        new_img = np.squeeze(t)
        cv.imwrite(new_img_path, new_img)
  return

# %%
techniques = ["FLIP", "BRIGHTNESS", "SATURATION", "CROP"]

for technique in techniques:
  augmentation(training_path, training_size, technique)

for technique in techniques:
  augmentation(val_path, training_size+validation_size, technique)

for technique in techniques:
  augmentation(t_path, training_size+validation_size+test_size, technique)

# %% [markdown]
# # Data Distribution

# %% [markdown]
# Training Data distribution:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/training/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/training/No_Goal"))
print("Goals found: ", goals)
print("No Goals found: ", no_goals)
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="green")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Goals found:  1147
# No Goals found:  1353

# %% [markdown]
# Validation Data Distribution:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/validation/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/validation/No_Goal"))
print("Validation distribution data.\nGoals: "+str(goals)+"\nNo Goals: "+str(no_goals))
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="blue")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Validation distribution data.
# Goals: 370
# No Goals: 430

# %% [markdown]
# **Test Data Distribution**:

# %%
goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/test/Goal"))
no_goals = len(os.listdir("/content/drive/MyDrive/VISIOPE/test/No_Goal"))
print("Test distribution data.\nGoals: "+str(goals)+"\nNo Goals: "+str(no_goals))
y = [goals, no_goals]
x = ['Goal', 'No Goal']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color="red")
plt.ylabel('Samples')
plt.xlabel('G/NG')
plt.title('Data Distribution')
plt.show()
# Out:
# Test distribution data.
# Goals: 186
# No Goals: 214

# %% [markdown]
# # CNN initizialization

# %% [markdown]
# With the **ImageDataGenerator** function we define the train and validation generator which allows us to:
#
# 1) Read images from the disk.
#
# 2) Decode contents of these images and convert it into proper grid format as per their RGB content.
#
# 3) Convert them into floating point tensors.
#
# 4) Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.

# %%
train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

# %% [markdown]
# Now, we can import from the right directory the data with **flow_from_directory** function. It also sets the batch_size and class_mode.
# For the training set we use a batch_size of 128 while for the validation set we use a batch_size of 32. Both of them has as class_mode the attribute binary, because the result of the cnn work is a binary classification: Goal, No Goal.

# %%
training_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/training/',
                                         target_size= (200,200),
                                         batch_size = 128,
                                         class_mode = 'binary')

validation_set = train.flow_from_directory('/content/drive/MyDrive/VISIOPE/validation/',
                                         target_size= (200,200),
                                         batch_size = 64,
                                         class_mode = 'binary')
# Out:
# Found 2500 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %% [markdown]
# Labels:
#
#
# *   Goal: 0
# *   No_Goal: 1

# %%
training_set.class_indices
# Out:
# {'Goal': 0, 'No_Goal': 1}

# %% [markdown]
# # CNN structure

# %% [markdown]
# Below the structure of the CNN is shown. It has:
#
#
# *   **3 Convolutional Layers:** the filter is a 5x5 matrix and 16, 32 and 64 as dimensionality of the output space according to the first, second and third layer. Each convolutional operation is followed by an activation function (relu)
# *   **3 MaxPooling Layers**: they follow each convolutional layer and help in reducing the spatial dimensions. It's used a 2x2 matrix to store the max pool operation
# *   The **Flatten Layer** converts the multi-dimensional image data array to 1D array
# *   **2 Dense Layers**: the first one has 512 as units value, it means that 512 is the output dimensionality and uses relu as activation function; the second one has 1 as units value, it means that it produces a single output which represents the predicted label. Since this is a binary classification task the sigmoid function is used as activation.

# %%
model = tf.keras.models.Sequential( [tf.keras.layers.Conv2D(16, (5,5), activation = 'relu', input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32, (5,5), activation='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64, (5,5), activation ='relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Flatten(),
                                    #
                                    tf.keras.layers.Dense(512, activation='relu'),
                                    #
                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                    ])

# %% [markdown]
# It's used as loss the binary cross entropy loss and Adam as optimizer. Learning rate is set to 0.001.

# %%
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics='accuracy')

# %% [markdown]
# To avoid inefficient computation time and space we use the Early Stopping method which stops the model process if the loss (in this case) doesn't decrement its value for 3 times.

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5)

# %% [markdown]
# # Results (DL)

# %%
model_fit = model.fit(training_set, 
                      steps_per_epoch = 3,
                      epochs = 20,
                      callbacks=[callback],
                      validation_data = validation_set)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 58s 22s/step - loss: 1.1633 - accuracy: 0.4974 - val_loss: 0.7773 - val_accuracy: 0.4625
# Epoch 2/20
# 3/3 [==============================] - 55s 22s/step - loss: 0.7279 - accuracy: 0.4948 - val_loss: 0.6775 - val_accuracy: 0.6012
# Epoch 3/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.6799 - accuracy: 0.5573 - val_loss: 0.6581 - val_accuracy: 0.6112
# Epoch 4/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.6515 - accuracy: 0.6146 - val_loss: 0.6540 - val_accuracy: 0.6125
# Epoch 5/20
# 3/3 [==============================] - 56s 22s/step - loss: 0.6476 - accuracy: 0.6094 - val_loss: 0.6315 - val_accuracy: 0.6363
# Epoch 6/20
# 3/3 [==============================] - 55s 22s/step - loss: 0.6158 - accuracy: 0.6745 - val_loss: 0.5982 - val_accuracy: 0.6637
# Epoch 7/20
# 3/3 [==============================] - 58s 22s/step - loss: 0.5583 - accuracy: 0.7344 - val_loss: 0.5677 - val_accuracy: 0.6963
# Epoch 8/20
# 3/3 [==============================] - 76s 32s/step - loss: 0.5229 - accuracy: 0.7448 - val_loss: 0.5298 - val_accuracy: 0.7713
# Epoch 9/20
# 3/3 [==============================] - 59s 23s/step - loss: 0.5243 - accuracy: 0.7474 - val_loss: 0.5009 - val_accuracy: 0.7962
# Epoch 10/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.3467 - accuracy: 0.8594 - val_loss: 0.5527 - val_accuracy: 0.8087
# Epoch 11/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.4158 - accuracy: 0.8229 - val_loss: 0.4424 - val_accuracy: 0.8650
# Epoch 12/20
# 3/3 [==============================] - 56s 23s/step - loss: 0.3754 - accuracy: 0.8516 - val_loss: 0.4003 - val_accuracy: 0.8600
# Epoch 13/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.3267 - accuracy: 0.8672 - val_loss: 0.4181 - val_accuracy: 0.8600
# Epoch 14/20
# 3/3 [==============================] - 57s 22s/step - loss: 0.3200 - accuracy: 0.8750 - val_loss: 0.4590 - val_accuracy: 0.8075
# Epoch 15/20
# 3/3 [==============================] - 76s 32s/step - loss: 0.2891 - accuracy: 0.8776 - val_loss: 0.4188 - val_accuracy: 0.8500
# Epoch 16/20
# 3/3 [==============================] - 56s 23s/step - loss: 0.2978 - accuracy: 0.8906 - val_loss: 0.3853 - val_accuracy: 0.8625

# %%
acc = model.history.history['accuracy']
val_accuracy = model.history.history["val_accuracy"]
plt.ylim(0,1)
plt.plot(acc, label="training accuracy")
plt.plot(val_accuracy, label="validation accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
loss = model.history.history["loss"]
val_loss = model.history.history["val_loss"]
plt.ylim(0,3)
plt.plot(loss, label="training loss")
plt.plot(val_loss, label="validation loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
def network_test():
  
  goal_path = "/content/drive/MyDrive/VISIOPE/test/Goal"
  no_goal_path = "/content/drive/MyDrive/VISIOPE/test/No_Goal"

  img_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/Goal")
  img_no_goal = os.listdir("/content/drive/MyDrive/VISIOPE/test/No_Goal")

  dim_goal = len(img_goal)
  dim_no_goal = len(img_no_goal)

  TP = 0
  TN = 0
  FP = 0
  FN = 0

  for i in os.listdir(goal_path):
    img = image.load_img(goal_path+"/"+str(i), target_size=(200,200,3))
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
      TP+=1
    else:
      FP+=1

  for i in os.listdir(no_goal_path):
    img = image.load_img(no_goal_path+"/"+str(i), target_size=(200,200,3))
    X = image.img_to_array(img)
    X = np.expand_dims(X, axis=0)
    images = np.vstack([X])
    val = model.predict(images)
    if val == 0:
      FN += 1
    else:
      TN += 1

  correct = TP+TN
  total_dim = dim_goal+dim_no_goal

  test_acc = correct/total_dim
  
  return test_acc, TP, TN, FP, FN

# %%
acc, TP, TN, FP, FN = network_test()
# Out:
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 57ms/step

# %% [markdown]
# Defining as:
#
#
# *   TP (true positive): Goals correctly classified as Goals
# *   TN (true negative): No Goals correctly classified as No Goals
# *   FP (false positive): No Goals wrongly classified as Goals
# *   FN (false negative): Goals wrongly classified as No Goals
#
# Let's print a bar with those values which are returned by the **network_test** function:

# %%
print("Test accuracy: ", acc)
y = [TP, FP, TN, FN]
x = ['TP', 'FP', 'TN', 'FN']
plt.figure(figsize=(6,5))
plt.bar(x, y, align="center", color=["blue", "red", "green", "orange"])
plt.title('Metrics')
plt.show()
# Out:
# Test accuracy:  0.77
